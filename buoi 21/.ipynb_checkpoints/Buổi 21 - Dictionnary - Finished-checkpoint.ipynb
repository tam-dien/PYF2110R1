# %% [markdown]
# # Dictionnary
#
# Dictionnary là một dạng list đặc biệt, nó khác list ở chỗ không lưu trữ các giá trị theo chỉ số vị trí, thay vào đó Dictionary sẽ lưu trữ các giá trị theo key
#
# ##### Tài liệu tham khảo: https://www.w3schools.com/python/python_dictionaries.asp
#
# ### Khai báo một dictionary
#
# Cú pháp:
#
# `<tên dictionary> = {}`
#
# ### Dictionary được khai báo bằng hai dấu hoặc nhọn
#
# Đây là một dictionary rỗng
#
# <b>Ví dụ 1:</b>
#
# `a = {}`
#
# a là một dictionary rỗng
#
# <b>Ví dụ 2:</b>
#
# `a = {"tên": "Nguyễn Tâm Điền", "tuổi": 13, "giới tính": "Nam"}`
#
# b là một dictionary có 3 key, mõi key đều có một giá trị riêng biệt
#
# Key có thể mang kiểu dữ liệu là chuỗi hoặc số
#
# ##### Mỗi một key đều phải có giá trị của riêng nó, không thể khai báo key không có giá trị
#
# <b>Hãy khai báo một dictionary có 3 phần tử</b>

# %%
a = {"abc":5,1:"hello",2:3.14}
print(a)
# Out:
# {'abc': 5, 1: 'hello', 2: 3.14}

# %% [markdown]
# ### Thêm key vào dictionary
#
# Cú pháp:
#
# `<tên dictionary>[<key>] = <giá trị>`
#
# <b>Ví dụ 1:</b>
#
# `a = {}
# a["tên"] = "NTD"`
#
# a là một dictionary có một phần tử, phần tử đó có key là "tên" và giá trị của key đó là "NTD"
#
# ##### Lưu ý, nếu trong trường hợp đã tồn tại key trong dictionary, dùng lệnh trên sẽ thay đổi giá trị key đó (không phải thêm key khác vào)
#
# <b>Ví dụ 2:</b>
#
# `a = {}
# a["tên"] = "NTD"
# a["tên"] = "Nguyễn Tâm Điền"`
#
# a vẫn là một dictionary có một phần tử, phần tử đó có key là "tên" và giá trị của key đó là "Nguyễn Tâm Điền"
#
# <b>Hãy khai báo một dictionary không có phần tử nào, sau đó thêm một phần tử vào dictionary đó</b>

# %%
a = {}
a["tên"] = "NTD"
a["tên"] = "Nguyễn Tâm Điền"
#print(len(a))
b = ("name" not in a)
print(b)
# Out:
# True

# %% [markdown]
# ### Truy xuất phần tử trong dictionary
#
# Cú pháp:
#
# `<tên dictionary>[<key>]`
#
# <b>Ví dụ:</b>
#
# `a = {"tên": "Nguyễn Tâm Điền", "tuổi": 13, "giới tính": "Nam"}
# print(a["tên"])`
#
# Màn hình sẽ in: Nguyễn Tâm Điền
#
# <b>Hãy khai báo một dictionary rồi in ra màn hình một phần tử bất kỳ trong dictionary đó</b>

# %%
a = {"0":5,"1":12,2:15}
print(a[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11756/207505671.py in <module>
#       1 a = {"0":5,"1":12,2:15}
# ----> 2 print(a[0])
#
# KeyError: 0

# %% [markdown]
# ### Sao chép dictionary
#
# ##### Việc sao chép dictionary được thực hiện hệt như sao chép list, chúng ta cần phải sử dụng lệnh copy()

# %% [markdown]
# ### Duyệt dictionary bằng lệnh for
#
# Cú pháp:
#
# `for <tên biến> in <tên dictionary>:`
#
# Biến sẽ có giá trị là từng key trong dictionary
#
# <b>Ví dụ:</b>
#
dict = {}
#trong văn bản có dấu ".", dấu ",", dấu "!", dấu "?"
b = "Lão"
if b not in dict:
    dict[b] = 1
else:
    dict[b] += 1
# Out:
#   File "C:\Users\tamdi\AppData\Local\Temp/ipykernel_11756/1219235187.py", line 3
#     trong văn bản có dấu ".", dấu ",", dấu
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
chuoi = "xin chào các bạn, xin chào mọi người"
## Chạy chương trình ở đây
## B1 viết cái hàm để tách chữ
## B2 là viết hàm đưa chữ vào dict
dict = {"xin" : 2, "chào" : 2, "các" : 1, "bạn" : 1, "mọi" : 1, "người" : 1}
for i in dict:
    print(i,":",dict[i])
# Out:
# xin : 2
# chào : 2
# các : 1
# bạn : 1
# mọi : 1
# người : 1

# %%
def xoakytu(s):
    s = s.replace(".","")
    s = s.replace(",","")
    s = s.replace("!","")
    s = s.replace("?","")
    s = s.replace(";","")
    s = s.replace(":","")
    s = s.replace("-","")
    s = s.replace("”","")
    s = s.replace("“","")
    s = s.lower()
    return s

### Đưa vào một chuỗi, lấy từ đầu + xóa từ đầu
def tachchu(s):
    c = s.find(" ")
    a = s[:c]
    s = s[c+1:]
    return s, a

def main(s):
    dict = {}
    s = xoakytu(s)
    s += " "
    while s != "":
        s, a = tachchu(s)
        if a not in dict:
            dict[a] = 1
        else:
            dict[a] += 1
    for i in dict:
        print(i,":",dict[i])
    

chuoi = "Lão Hạc thổi cái mồi rơm, châm đóm. Tôi đã thông điếu và bỏ thuốc rồi. Tôi mời lão hút trước. Nhưng lão không nghe... - Ông giáo hút trước đi. Lão đưa đóm cho tôi... - Tôi xin cụ... Và tôi cầm lấy đóm, vo viên một điếu. Tôi rít một hơi xong, thông điếu rồi mới đặt vào lòng lão. Lão bỏ thuốc, nhưng chưa hút vội. Lão cầm lấy đóm, gạt tàn, và bảo: - Có lẽ tôi bán con chó đấy, ông giáo ạ! Lão đặt xe điếu, hút. Tôi vừa thở khói, vừa gà gà đôi mắt của người say, nhìn lão, nhìn để làm ra vẻ chú ý đến câu nói của lão đó thôi. Thật ra thì trong lòng tôi rất dửng dưng. Tôi nghe câu ấy đã nhàm rồi. Tôi lại biết rằng: lão nói là nói để có đấy thôi; chẳng bao giờ lão bán đâu. Vả lại, có bán thật nữa thì đã sao? Làm quái gì một con chó mà lão có vẻ băn khoăn quá thế... Lão hút xong, đặt xe điếu cuống, quay ra ngoài, thở khói. Sau một điếu thuốc lào, óc người ta tê dại đi trong một nỗi đê mê nhẹ nhõm. Lão Hạc ngồi lặng lẽ, hưởng chút khoái lạc con con ấy. Tôi cũng ngồi lặng lẽ. Tôi nghĩ đến mấy quyển sách quý của tôi. Hồi bị ốm nặng ở Sài Gòn tôi bán gần hết cả áo quần, nhưng vẫn không chịu bán cho ai một quyển. Ốm dậy, tôi về quê, hành lý chỉ vẻn vẹn có một cái va-ly đựng toàn những sách. Ôi những quyển sách rất nâng niu! Tôi đã nguyện giữ chúng suốt đời, để lưu lại cái kỷ niệm một thời chăm chỉ,
# điền : 1
# rân : 1
# rấn : 1
# nước : 1
# khi : 1
# ba : 4
# chả : 1
# gửi : 1
# vay : 1
# biếu : 1
# thầy : 3
# thỉnh : 1
# thoảng : 1
# ăn : 3
# quà : 1
# xưa : 1
# bữa : 1
# bòn : 1
# thuê : 1
# mướn : 1
# chuyến : 1
# sống : 2
# nhục : 1
# khóc : 1
# chụp : 1

# %% [markdown]
# Viết chương trình cho phép người dùng quản lý sản phẩm, gồm các chức năng sau:
#
# - Hiển thị danh sách sản phẩm
# - Thêm sản phẩm mới vào danh sách
# - Sửa tên của sản phẩm trong danh sách
# - Xoá một sản phẩm khỏi danh sách

# %%
ds = {"123":"Cơm gà","234":"cơm sườn"}

# %%
print("Mời nhập các phím theo các chức năng như sau:")
print("H: Hiển thị danh sách sản phẩm")
print("T: Thêm sản phẩm mới vào danh sách")
print("S: Sửa tên của sản phẩm trong danh sách")
print("X: Xoá một sản phẩm khỏi danh sách")
print("0: Thoát chương trình")
a = input("Mời nhập chức năng:")
while (a != "0"):
    print("----------------------------")
    print("")
    if a == "H":
        if (len(ds) == 0):
            print("Danh sách rỗng!")
        else:
            for key in ds:
                print(key,":",ds[key])
    elif a == "T":
        key = input("Mời nhập ID sản phẩm (nếu muốn thoát thêm thì nhập 0):")
        while key in ds:
            print("ID đã tồn tại! Mời nhập lại ID khác!")
            key = input("Mời nhập ID sản phẩm (nếu muốn thoát thêm thì nhập 0):")
        if (key != "0"):   
            ds[key] = input("Mời nhập tên sản phẩm:")
    elif a == "S":
        print("Các sản phẩm hiện có:")
        for key in ds:
            print(key,":",ds[key])
        key = input("Mời nhập ID sản phẩm bạn muốn sửa:")
        ds[key] = input("Mời nhập tên sản phẩm mới:")
    elif a == "X":
        print("Các sản phẩm hiện có:")
        for key in ds:
            print(key,":",ds[key])
        key = input("Mời nhập ID muốn xóa (nếu muốn thoát thêm thì nhập 0):")
        if (key != "0"):
            while key not in ds:
                print("ID sản phẩm này không có trong danh sách! Vui lòng nhập lại!")
                key = input("Mời nhập ID muốn xóa (nếu muốn thoát xóa thì nhập 0):")
                if (key == "0"):
                    break
            if (key != "0"):
                if (input("Bạn có chắc muốn xóa? (Nhập C nếu chắc chắn, nhập bất kỳ nếu không chắc chắn)" ) == "C"):
                    ds.pop(key)
    print("")
    print("----------------------------")   
    a = input("Mời nhập chức năng:")
# Out:
# Mời nhập các phím theo các chức năng như sau:
# H: Hiển thị danh sách sản phẩm
# T: Thêm sản phẩm mới vào danh sách
# S: Sửa tên của sản phẩm trong danh sách
# X: Xoá một sản phẩm khỏi danh sách
# 0: Thoát chương trình
# Mời nhập chức năng:X
# ----------------------------
#
# Các sản phẩm hiện có:
# 123 : Cơm gà
# 234 : cơm sườn
# Mời nhập ID muốn xóa (nếu muốn thoát thêm thì nhập 0):123
# Bạn có chắc muốn xóa? (Nhập c, nếu chắc chắn, k nếu không chắc chắn)c
#
# ----------------------------
# Mời nhập chức năng:H
# ----------------------------
#
# 234 : cơm sườn
#
# ----------------------------
# Mời nhập chức năng:0
